# %%
import numpy as np
import pandas as pd
import scipy
from datetime import datetime
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
raw = pd.read_csv('ethereum_price.csv')

# %%
df = raw[['Date', 'Close']].copy()
df['Date'] = pd.to_datetime(df['Date'], format='%b %d, %Y')
df.sort_values('Date', inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         Date     Close
# 0 2015-08-07  2.770000
# 1 2015-08-08  0.753325
# 2 2015-08-09  0.701897
# 3 2015-08-10  0.708448
# 4 2015-08-11  1.070000

# %%
ts = df.set_index('Date')

# %%
plt.figure(figsize=(11,6))
plt.plot(ts)
plt.show()

# %%
import ruptures as rpt
breaks = rpt.Pelt(model='rbf').fit_predict(ts, pen=10)

rpt.display(ts, breaks, figsize=(11,6))
plt.show()
